# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('input/tpm.csv')

# %%
dfbx = df[df<20]
dfbxz = dfbx[df>0]
dfbxz.hist(bins=50, figsize=(10,10))
#plt.xlim(0,100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcc87b624a8>,
# ...
#       dtype=object)
